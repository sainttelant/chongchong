# %%
import os
import time
from collections import deque
 


def change_file_name(path):  #传入的就是文件名, 这个函数的目的是修改inl函数，确保改名不覆盖 
    #print("放入到change_name的路径：",path)
    path_arr = path.split('.')
    #filename_pre=path_arr[0]
    if len(path_arr)==1:
        print("这个文件有问题，没有后缀名,经验证可以打开，直接copy，哈哈：",path_arr[0])
        return None
    elif len(path_arr)==2:
        filename_pre=path_arr[0]
        filename_after=path_arr[1]
        if filename_after=="inl":
            dst_file='%s.%s'%(filename_pre+"_nl","html")
        else:
            dst_file = '%s.%s'%(filename_pre,"html")
        return dst_file;


def getDirAndCopyFile(sourcePath,targetPath):
    if not os.path.exists(sourcePath):
        return
    if not os.path.exists(targetPath):
        os.makedirs(targetPath)
     
    #遍历文件夹
    for fileName in os.listdir(sourcePath):
        #拼接原文件或者文件夹的绝对路径
        absourcePath = os.path.join(sourcePath, fileName)
        #拼接目标文件或者文件加的绝对路径
        abstargetPath = os.path.join(targetPath, fileName)
        #判断原文件的绝对路径是目录还是文件
        if os.path.isdir(absourcePath):
            #是目录就创建相应的目标目录
            os.makedirs(abstargetPath)
            #递归调用getDirAndCopyFile()函数
            getDirAndCopyFile(absourcePath,abstargetPath)#是文件就进行复制
        if os.path.isfile(absourcePath):
            nameoffile=absourcePath.split('/')[-1]
            #print("是文件，打印当前的absourcePath的文件名:",nameoffile)
            newname=change_file_name(nameoffile)
            rbf = open(absourcePath,"rb")
            need2removedstr=abstargetPath.split('/')[-1]
            prepinjie=abstargetPath.replace(need2removedstr,"")
            if newname!=None:
                abstargetPathNew=os.path.join(prepinjie,newname)
                wbf = open(abstargetPathNew,"wb")
                while True:
                    content = rbf.readline(1024*1024)
                    if len(content)==0:
                        break
                    wbf.write(content)
                    wbf.flush()
                rbf.close()
                wbf.close()
            elif newname==None:
                #print("这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径：",abstargetPath)
                wbf = open(abstargetPath,"wb")
                while True:
                    content = rbf.readline(1024*1024)
                    if len(content)==0:
                        break
                    wbf.write(content)
                    wbf.flush()
                rbf.close()
                wbf.close()
if __name__ == '__main__':
    
    startTime = time.clock()
    sourcePath = input("请输入源路径：")
    targetPath = input("请输入copy路径：")
    getDirAndCopyFile(sourcePath,targetPath)
    #时间是用来计算复制总共消耗了多少时间
    endTime = time.clock()
    time_mi = endTime // 60
    time_s = endTime // 1 % 60
    time_ms = ((endTime * 100) // 1) % 100
    print ("总用时:%02.0f:%02.0f:%2.0f" % (time_mi, time_s, time_ms))
# Out:
# 请输入源路径：kek
# 请输入copy路径：kek1
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/template/DiagnosticDataList_PROJECT.csv.xml_tpl
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/template/STM_Signal2State_CallbackFunctions_COMMON.txt.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/template/SSI_VirtualNode_CallbackFunctions_COMMON.txt.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_testsuite/DSW09_TestSuite_NvMStub_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dim_fmhc/Test_DIM_FMHC_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dim_fmhc/Test_Delete_FaultLevel_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/cm/Test_DSW_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dia_sfb/Test_DIA_SFB_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dim_dtc/Test_DIM_DTC_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/stm/Test_STM_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dia_cdb/Test_DIA_CDB_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dia_cdb/Test_DIA_CDB_TF_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/var/Test_DSW_VarCodeHandling_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dim_env/Test_ENV_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dia_mft/FailureSensitivityManipulation.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dia_mft/Test_DIA_MFT_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dia_mft/FailureSensitivityManipulation_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dim_fmhobd/Test_DIM_FMHOBD.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/fim_adapter/Test_STM02_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/smm/Test_SMM_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dia_ssi/Test_DIA_SSI_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dia_ssi/Test_HWStateControl_Main_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/Test_Undefined_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/STM_ScheduledComponentList_COMMON.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/MFT_MID2StringMap_Common.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/STM_StateLimiter2StringMap_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/CDB_TFID2StringMap_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/DTC_DTCID2StringMap_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/Test_ID2StringMap_DTCID_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/Test_ID2StringMap_CID_ERR_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/CDB_ERR2StringMap_Common.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/SSI_SID2StringMap_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/STM_ScheduledComponentList_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/STM_StateLimiter2StringMap_Common.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/CDB_ERR2StringMap_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/SSI_SID2StringMap_Common.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/CDB_TFID2StringMap_Common.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/Test_ID2StringMap_SID_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/Test_ID2StringMap_MID_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/DIA_MIDString_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/MFT_MID2StringMap_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/DTC_DTCID2StringMap_Common.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/CDB_CID2StringMap_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dsw_forsimulation/CDB_CID2StringMap_Common.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dim_fmhrb/Test_DIM_FMHRB_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/test/dem_adapter/Test_DEM_PRJ.csi.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_fmhc/FMHC_Base_COMMON.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_fmhc/FMHC_FaultRecord_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/cm/DSW_ConfigurationID_Common.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/cm/DSW_Configuration_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_dtc/DTC_DiagnosticTroubleCodes_Common.pdm.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_dtc/DTC_DiagnosticTroubleCodes_Common.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_dtc/DTC_DTCID_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_dtc/DTC_Mapping_MID_DTCID_Common.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_dtc/DTC_Mapping_MID_DTCID_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_dtc/DTC_TestFailedSLC_Config_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_dtc/DTC_DTCCode_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/pdm2nvm_adapter/DSW4BSW_PDM2NVM_Cb_Cfg.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/pdm2nvm_adapter/DSW4BSW_PDM2NVM_Cfg.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/pdm2nvm_adapter/DSW4BSW_PDM2NVM_Cb_Cfg.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/stm/STM_Processing_COMMON.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/stm/STM_Component_COMPNAME_COMMON.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/stm/STM_Signal2State_CallbackFunctions_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/stm/STM_SystemList_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/stm/STM_Component_COMPNAME_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/stm/STM_ComponentConfiguration_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/stm/STM_SSC_COMPNAME_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/stm/STM_SSC_ComponentGoodcheck_Common.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/stm/STM_SSC_COMPNAME_Common.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/stm/STM_ComponentList_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_cdb/DIA_CDB_TimeFilter_ProjectConfig_Common.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_cdb/DIA_CDB_Methods_ProjectConfig_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_cdb/DIA_CDB_ErrorRate_ProjectConfig_Common.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_cdb/DIA_CDB_ErrorRate_ProjectConfig_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_cdb/DIA_CDB_TimeFilter_ProjectConfig_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_cdb/DIA_CDB_TimeFilter_Config_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_cdb/DIA_CDB_FailureFilter_ProjectConfig_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_cdb/DIA_CDB_FailureFilter_ProjectConfig_Common.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/var/DSW_VarCodeHandling_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/var/DSW_VarCodeHandling_Common.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/var/DSW_VarCodeHandlingDef_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_mft/DIA_MFT_MID_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_mft/DIA_MFT_Monitoring_ProjectConfig_Common.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_mft/MFT_SituationList_Common.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_mft/DIA_MonitoringCategory_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_mft/DIA_MFT_Measurement_COMMON.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_mft/MFT_SituationList_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_mft/DIA_MFT_Monitoring_ProjectConfig_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_mft/Dem_EnableConditionConfig_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_mft/Dem_EnableConditionConfig_Common.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_mft/DIA_MFT_TestComplete_Common.pdm.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_mft/MFT_TestCompleteSLC_Config_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_fmhobd/dfes2fmh_adapter_auto_pub_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_fmhobd/fmhobd_SecondaryDTCsHandler_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_fmhobd/fmhobd_SecondaryDTCsHandler_Common.pdm.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_fmhobd/fmhobd_SecondaryDTCs_TCSLC_Config_Common.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_fmhobd/dfes2fmh_adapter_ConfigCommon.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/fim_adapter/STM02_COMMON.C.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/fim_adapter/STM02_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/fim_adapter/Fim_Fids_Cfg.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/DTCInfo_Common.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/List_System_Release_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/SystemStateMatrix_ByNumber_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/STM02_FimInhibitMatrix_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/TC_ManeuverDescription_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/MFT_DemEnableConditionMatrix_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/SystemStateMatrix_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/DiagnosticDataList_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/List_StateLimters_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/List_TC_Maneuvers_MIDs_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/MasterSlaveDependencies_Common.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/DSW_BitArrayEEPROM_COMMON.txt.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/AncestorList_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/List_MIDs_TC_Maneuvers_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/MFT_SituationFilterMatrix_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/List_System_States_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/List_Failure_DependencyStructure_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/List_DTC_TC_Maneuvers_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/List_Nodes_DependencyStructure_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/doc/List_Monitorings_Nodes_Alphabetic_Order_COMMON.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/smm/SMM_CONFIG_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/smm/SMM_RequesterList_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/smm/SMM_Requester_ProjectConfig_COMMON.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/smm/SMM_Requester_ProjectConfig_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_ssi/DIA_SSI_VirtualNode_ProjectConfig_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_ssi/DIA_SSI_Node_ProjectConfig_COMMON.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_ssi/DIA_SSI_Node_ProjectConfig_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_ssi/DIA_SSI_SID_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dia_ssi/DIA_SSI_VirtualNode_ProjectConfig_COMMON.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_fmhrb/RBFailureMemory_COMMON.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_fmhrb/RBFailureMemory_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dim_fmhrb/FMHRB_FaultRecord_COMMON.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dem_adapter/Dem_EnableConditionIds_Project.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dem_adapter/DEM_DiaAdapter_COMMON.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/scripts/dem_adapter/Dem_EventIds_Project.h.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/tools/mm6/SMM02_Mes_COMMON.cfg.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/tools/mm6/DTC_Measurement_COMMON.cfg.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/tools/mm6/STM_Mes_COMMON.cfg.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/tools/mm6/DIA_Measurement_Min_COMMON.cfg.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/tools/mm6/DIA_Measurement_COMMON.cfg.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/doc/autosar/Dem_Cfg_SWCD.arxml.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/doc/autosar/Fim_Cfg_SWCD.arxml.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_Common/src/pdm_config/DSW_PdmLifetimeParameters_Config.pdmdb.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_AdapterTpl/tpl/DSW_gen_Cfg.py.tpl
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_AdapterTpl/tpl/DiamantPro.ini.tpl
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_AdapterTpl/tpl/DSW_Common.py.tpl
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_AdapterTpl/tpl/DSW_BuildFileList.txt.tpl
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_AdapterTpl/tpl/DSW_Dummy02.h.tpl
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_AdapterTpl/tpl/DIAMANT_FileList_PROJECT.tfl.tpl
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_AdapterTpl/tpl/DSW_Adapter_Cfg.py.tpl
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_AdapterTpl/tpl/CM_Settings_Prj.CFG.tpl
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_AdapterTpl/tpl/DSW_Project_Cfg.py.tpl
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_ProjectTpl/STM_Signal2State_CallbackFunctions_COMMON.txt.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_ProjectTpl/DiagnosticDataList_PROJECT.csv.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_ProjectTpl/extras/FW_SymptomByte_Common.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_ProjectTpl/extras/DTC_Severity_Common.c.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Diagnosis/DSW/DSW_ProjectTpl/SSI_VirtualNode_CallbackFunctions_COMMON.txt.xml
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/doc/CRC.pl.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc.h.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_64BitFinishNoXor.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P18005r.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_Private.h.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P110211021uOT.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P1X001BrET.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P12Fu.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_P1X001BronComp.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_64BitFinishXor.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P107r.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc.h.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P110211021uOT.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_64BitZeroInit.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P1X001BuET.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/Crc_Call.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_64BitOneInit.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P107u.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P104C11DB7r.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P12Fu.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/Crc_Call.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P110211021rOT.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_P1X001BuonComp.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P107u.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_P1X001BuonComp.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P110211021rOT.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P11DrT8.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_64BitFinishNoXor.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P11021rOT.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_64BitOneInit.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P11Du.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P11021rOT.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P187r.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P1X001BuET.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P11DrT8.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_64BitFinishXor.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P107r.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_64BitZeroInit.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_P1X001BronComp.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_Private.h.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P18005r.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P1X001BrET.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P187r.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P104C11DB7r.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-16/rba_CCrc_I_P11Du.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc.h.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_64BitFinishNoXor.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P18005r.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_Private.h.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P110211021uOT.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P1X001BrET.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P12Fu.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_P1X001BronComp.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_64BitFinishXor.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P107r.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc.h.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P110211021uOT.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_64BitZeroInit.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P1X001BuET.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/Crc_Call.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_64BitOneInit.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P107u.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P104C11DB7r.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P12Fu.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/Crc_Call.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P110211021rOT.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_P1X001BuonComp.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P107u.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_P1X001BuonComp.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P110211021rOT.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P11DrT8.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_64BitFinishNoXor.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P11021rOT.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_64BitOneInit.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P11Du.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P11021rOT.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P187r.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P1X001BuET.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P11DrT8.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_64BitFinishXor.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P107r.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_64BitZeroInit.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_P1X001BronComp.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_Private.h.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P18005r.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P1X001BrET.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P187r.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P104C11DB7r.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/SecLibs/rbaCCrc/quality/Qac/qac-report-32/rba_CCrc_I_P11Du.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/testRT/rbcAssertStatic/rbcAssertStatic.atc.txt
# 这个文件有问题，没有后缀名： options
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/polyspace/results001/ALL/PASS4/options
# 这个文件有问题，没有后缀名： options
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/polyspace/results001/ALL/PASS2/options
# 这个文件有问题，没有后缀名： options
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/polyspace/results001/ALL/PASS0/options
# 这个文件有问题，没有后缀名： options
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/polyspace/results001/ALL/PASS3/options
# 这个文件有问题，没有后缀名： options
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/polyspace/results001/ALL/PASS1/options
# 这个文件有问题，没有后缀名： options
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/polyspace/results001/options
# 这个文件有问题，没有后缀名： Makefile
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/splint/Makefile
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/qac/qac-report-001/rbcAssertStatic.h.sum
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/qac/qac-report-001/rbcAssertStatic_Call.c.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/qac/qac-report-001/rbcAssertStatic_Call.c.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/qac/qac-report-001/rbcAssertStatic.h.html
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/qac/qac-report-001/rbcAssertStatic_Call.c.err
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/qac/qac-report-001/rbcAssertStatic_Call.c.sum
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/qac/qac-report-001/rbcAssertStatic.h.i
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/qac/qac-report-001/rbcAssertStatic.h.txt
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/qac/qac-report-001/rbcAssertStatic.h.err
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/qac/qac-report-001/rbcAssertStatic_Call.c.i
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/qac/qac-report-001/rbcAssertStatic_Call.c.met
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/qac/qac-report-001/rbcAssertStatic.h.met
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/quality/qac/qac_make.pl.html
# 这个文件有问题，没有后缀名： Makefile
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/development/testenv/Makefile
# 这个文件有问题，没有后缀名： Makefile
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/development/testTC30/Makefile
# 这个文件有问题，没有后缀名： Makefile
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/development/testTMS470/Makefile
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/development/tools/RemCMKeys.pl.html
# 这个文件有问题，没有后缀名： Makefile
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/development/Makefile
# 这个文件有问题，没有后缀名： Makefile
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/development/testHC12X/Makefile
# 这个文件有问题，没有后缀名： Makefile
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/rbaCAssertCompile/development/doxygen/Makefile
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/Fls/rba_FlsTi/api/rba_FlsTi_Api_CGT.CCS.h
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/Fls/rba_FlsTi/api/rba_FlsTi_Api_CGT.GHS.h
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/Fls/rba_FlsTi/api/rba_FlsTi_Api_CGT.gcc.h
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/Fls/rba_FlsTi/api/rba_FlsTi_Api_CGT.IAR.h
# 这他妈文件有问题，没有后缀名，我就直接copy操作了，下面跟一下它的路径： kek1/arc/Mem/Fls/rba_FlsTi/api/rba_FlsTi_Api_CGT.ARM.h
# 总用时:00:04: 1

# %%
text='shiyan/arc_api/AgeingMeter_Config_Common.h'
a=text.split('/')[-1]
print(text.replace(a,""))
