# %%
import requests
from bs4 import BeautifulSoup as bs
from multiprocessing import Pool
import os,re
import time

s=requests.Session()
s.keep_alive = False
headers={'Connection':'keep-alive',
'Host':'hm.baidu.com',
'Referer':'https://www.219ii.com/htm/piclist6/',
'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
pageNum=15
img_url=[]
name=[]
tupurl=[]

def get_img_url():
    for i in range(1,pageNum):   
        url='https://www.219ii.com/htm/piclist4/'
        url=url+str(i)+".htm"
        print(url)
        scaleurl=url.replace('/htm/piclist4/',"").replace(str(i)+".htm","")
        print(scaleurl)
        re=s.get(url)
        if re.status_code==200:
            re.encoding='utf-8'
            #print(re.text)
            soup=bs(re.text,'lxml')
            for url in soup.select('div.mainArea ul.textList li a'):
                url1=scaleurl+url['href']
                filename=url.get_text()
                name.append(filename)
                img_url.append(url1)
            return img_url,name

        print('爬虫被禁了',re.status_code)
        return None

def createDir(nm):
    path='chongzi/pic/'+nm+'/'
    if not os.path.exists(path):
        os.makedirs(path)
    return path
    

def crawlpicurl(url,name):
    for (k,nm) in zip(url,name):
        re=s.get(k)
        path=createDir(nm)
        if re.status_code==200:
            re.encoding='utf-8'
            soup=bs(re.text,'lxml')
            count=0
            for tuurl in soup.select('div.mainAreaBlack div.picContent img'):
                count+=1
                src=tuurl['src']
                req=s.get(src)   #对具体图片进行操作了，get操作
                nr=req.content
                filename=path+nm+str(count)+'.jpg'
                print(filename)
                with open(filename,'wb') as f:
                    f.write(nr)        
        else:
            print('爬虫被禁了')   
        print('下载完成',nm)        


if __name__ == "__main__":
    pool=Pool(5)
    url,name=get_img_url()
    
    pool.apply_async(crawlpicurl(url,name))
    pool.close()
    pool.join()
# Out:
# https://www.219ii.com/htm/piclist4/1.htm
# https://www.219ii.com
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]1.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]2.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]3.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]4.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]5.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]6.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]7.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]8.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]9.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]10.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]11.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]12.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]13.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]14.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]15.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]16.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]17.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]18.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]19.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]20.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]21.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]22.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]23.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]24.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]25.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]26.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]27.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]28.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]29.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]30.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]31.jpg
# chongzi/pic/06-16性感丝袜美腿诱惑少妇图片[32P]/06-16性感丝袜美腿诱惑少妇图片[32P]32.jpg
# 下载完成 06-16性感丝袜美腿诱惑少妇图片[32P]
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]1.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]2.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]3.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]4.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]5.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]6.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]7.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]8.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]9.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]10.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]11.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]12.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]13.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]14.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]15.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]16.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]17.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]18.jpg
# chongzi/pic/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]/06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]19.jpg
# 下载完成 06-16穿着粉色内衣的女人诱人白嫩性感的肌肤[19P]
# chongzi/pic/06-16装修女工肉丝美腿[44P]/06-16装修女工肉丝美腿[44P]1.jpg
# chongzi/pic/06-16装修女工肉丝美腿[44P]/06-16装修女工肉丝美腿[44P]2.jpg
# chongzi/pic/06-16装修女工肉丝美腿[44P]/06-16装修女工肉丝美腿[44P]3.jpg
# chongzi/pic/06-16装修女工肉丝美腿[44P]/06-16装修女工肉丝美腿[44P]4.jpg
# chongzi/pic/06-16装修女工肉丝美腿[44P]/06-16装修女工肉丝美腿[44P]5.jpg
# chongzi/pic/06-16装修女工肉丝美腿[44P]/06-16装修女工肉丝美腿[44P]6.jpg
# chongzi/pic/06-16装修女工肉丝美腿[44P]/06-16装修女工肉丝美腿[44P]7.jpg
# chongzi/pic/06-16装修女工肉丝美腿[44P]/06-16装修女工肉丝美腿[44P]8.jpg
# chongzi/pic/06-16装修女工肉丝美腿[44P]/06-16装修女工肉丝美腿[44P]9.jpg
# chongzi/pic/06-16装修女工肉丝美腿[44P]/06-16装修女工肉丝美腿[44P]10.jpg
# chongzi/pic/06-16装修女工肉丝美腿[44P]/06-16装修女工肉丝美腿[44P]11.jpg
# chongzi/pic/06-16装修女工肉丝美腿[44P]/06-16装修女工肉丝美腿[44P]12.jpg
# chongzi/pic/06-16装修女工肉丝美腿[44P]/06-16装修女工肉丝美腿[44P]13.jpg
# chongzi/pic/06-16装修女工肉丝美腿[44P]/06-16装修女工肉丝美腿[44P]14.jpg
