# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup as bs
from PIL import Image
import datetime
from urllib import parse
import re
import random
import time
from io import BytesIO
import json
import os

s=requests.Session()
headers={
            'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
            'accept-encoding':'gzip, deflate, br',
            'accept-language':'en-US,en;q=0.8',
            'referer':'https://product.360che.com/BrandList.html',
            'upgrade-insecure-requests':'1',
            'user-agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
        }

url='https://product.360che.com/BrandList-1.html'
subclass_list=[]
suburl_list=[]
os.makedirs("truckLogs")


def title(url):
    classlist=[]
    html=s.get(url,headers=headers)
    soup=bs(html.text,'lxml')
    classoftruck=soup.select(".sel-act")[0].get_text()
    subclass=soup.select("div.xll_center2_a1_y1 a")
    for i in subclass:
        classlist.append(i.get_text())
    return classoftruck,classlist
def crawlPic(url):
    html=s.get(url,headers=headers)
    soup=bs(html.text,"lxml")
    picoverall=soup.select("div.xll_center2_a1_z dl dt a img")
    for i in picoverall:
        picurl=i['src']
        try:
            if "/" in i['title']:
                inew=i['title'].replace("/","_")
                picname=inew+i["src"].split("https://img4.kcimg.cn/imgser/")[1].split("!")[0]
                
            picname=i['title']+i["src"].split("https://img4.kcimg.cn/imgser/")[1].split("!")[0]
            #print(picname)
            piccontent=s.get(picurl,headers=headers)
            if piccontent.status_code==200:
                print(i["title"])
                print(i["src"])
                f=open('truckLogs/'+picname,"wb")
                f.write(piccontent.content)
                f.close()
        except IndexError:
            print("ingore no pictitle's problem")
        else:
            print("it should be downloaded!")
            
        

def suburl():
    html=s.get(url,headers=headers).content
    soup=bs(html,'html.parser')
    suburls=soup.select("div.lbpd-box a")
    for i in suburls:
        newurl=url.split("BrandList-1.html")[0]+i['href']
        suburl_list.append(newurl)
    return suburl_list


if __name__=="__main__":
    print("<<<<<<<<It is begin to crawl car classifier for marketing depart>>>>>>")
    data_d=dict()
    suburls_L=suburl()
    for url in suburls_L:
        Bigclass,subclass=title(url)
        
        crawlPic(url)
        data_d[Bigclass]=subclass
    print("all done")
# Out:
# <<<<<<<<It is begin to crawl car classifier for marketing depart>>>>>>
# 奔驰
# https://img4.kcimg.cn/imgser/20181206052211b63b2587aa7a.png!120
# it should be downloaded!
# 北奔重卡
# https://img4.kcimg.cn/imgser/20181206052024e23824fad7a2.png!120
# it should be downloaded!
# 北汽黑豹
# https://img4.kcimg.cn/imgser/20181206052059b959361198e4.png!120
# it should be downloaded!
# 比亚迪
# https://img4.kcimg.cn/imgser/201812060522427e0fe82754a0.png!120
# it should be downloaded!
# 北京牌
# https://img4.kcimg.cn/imgser/201812060520414225e34862ba.png!120
# it should be downloaded!
# 北汽新能源
# https://img4.kcimg.cn/imgser/2018120605215301a36f4cc15d.png!120
# it should be downloaded!
# BMC
# https://img4.kcimg.cn/imgser/20181206051951bfb9b0e145b2.png!120
# it should be downloaded!
# 北汽威旺
# https://img4.kcimg.cn/imgser/20181206052135a5a3d200703a.png!120
# it should be downloaded!
# 宝骐汽车
# https://img4.kcimg.cn/imgser/2018120605201099d82aa4092f.png!120
# it should be downloaded!
# 博雷顿
# https://img4.kcimg.cn/imgser/20181206052302b0ec08568821.png!120
# it should be downloaded!
# 北斗航天
# https://img4.kcimg.cn/imgser/201905161150255c1f3a42627f.png!120
# it should be downloaded!
# 北汽幻速
# https://img4.kcimg.cn/imgser/20181206052117fdf12eb71a7a.png!120
# it should be downloaded!
# 长安跨越
# https://img4.kcimg.cn/imgser/20181206052425705ddacd8360.png!120
# it should be downloaded!
# 长安轻型车
# https://img4.kcimg.cn/imgser/201901140533143dc21f4e393f.png!120
# it should be downloaded!
# 长城汽车
# https://img4.kcimg.cn/imgser/2018120605252204eda1d0e459.png!120
# it should be downloaded!
# 昌河汽车
# https://img4.kcimg.cn/imgser/20181206052316874764dac445.png!120
# it should be downloaded!
# 川交汽车
# https://img4.kcimg.cn/imgser/20181206052348c6b2469d1cd4.png!120
# it should be downloaded!
# 长征汽车
# https://img4.kcimg.cn/imgser/201812060526131da4be8f68a6.png!120
# it should be downloaded!
# 长丰集团
# https://img4.kcimg.cn/imgser/2018120605253840da17ce7752.png!120
# it should be downloaded!
# 长安重汽
# https://img4.kcimg.cn/imgser/20181206052502d54a5b8a73ce.png!120
# it should be downloaded!
# 长江汽车
# https://img4.kcimg.cn/imgser/201812060525595cc34991c013.png!120
# it should be downloaded!
# 成功汽车
# https://img4.kcimg.cn/imgser/20181206052334dbdbd781adb2.png!120
# it should be downloaded!
# 成都雅骏
# https://img4.kcimg.cn/imgser/201812060524100d66e3fe2934.png!120
# it should be downloaded!
# ingore no pictitle's problem
# 东风商用车
# https://img4.kcimg.cn/imgser/2016052012350507064181fa0b.png!120
# it should be downloaded!
# 东风柳汽
# https://img4.kcimg.cn/imgser/201708220933477d2da78975d7.png!120
# it should be downloaded!
# 大运轻卡
# https://img4.kcimg.cn/imgser/2016070810370535857b1cf531.png!120
# it should be downloaded!
# 东风华神
# https://img4.kcimg.cn/imgser/201906250221516fc731badfad.png!120
# it should be downloaded!
# 大运重卡
# https://img4.kcimg.cn/imgser/20160520013210b5c1cf28ccde.png!120
# it should be downloaded!
# 东风小康
# https://img4.kcimg.cn/imgser/201809040439577a4f70abfc35.png!120
# it should be downloaded!
# 东风新疆(原专底/创普)
# https://img4.kcimg.cn/imgser/201608090402014db9b78e78cb.png!120
# ------------------------------------------------------------
# FileNotFoundError          Traceback (most recent call last)
# <ipython-input-95-61510b6f0178> in <module>()
#      77         Bigclass,subclass=title(url)
#      78
# ---> 79         crawlPic(url)
#      80         data_d[Bigclass]=subclass
#      81     print("all done")
#
# <ipython-input-95-61510b6f0178> in crawlPic(url)
#      50                 print(i["title"])
#      51                 print(i["src"])
# ---> 52                 f=open('truckLogs/'+picname,"wb")
#      53                 f.write(piccontent.content)
#      54                 f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'truckLogs/东风新疆(原专底/创普)201608090402014db9b78e78cb.png'

# %%
kk="https://img4.kcimg.cn/imgser/2016070704314183e3f3540e79.png!120"
kk.split("https://img4.kcimg.cn/imgser/")[1].split("!")[0]
kkk='东风新疆(原专底/创普)'
kne=kkk.replace("/","_")
kne
# Out:
# '东风新疆(原专底_创普)'

# %%
data_d.keys()
# Out:
# dict_keys(['皮卡品牌', '不限', '电动卡车品牌', '专用车品牌', '微型车品牌', '配件品牌', '挂车品牌', '卡车品牌', '工程车品牌', '封闭货车品牌'])

# %%
for i in data_d.values():
    print(len(i))
    
for j in data_d.keys():
    print(j)
# Out:
# 43
# 194
# 106
# 158
# 23
# 206
# 16
# 128
# 82
# 48
# 皮卡品牌
# 不限
# 电动卡车品牌
# 专用车品牌
# 微型车品牌
# 配件品牌
# 挂车品牌
# 卡车品牌
# 工程车品牌
# 封闭货车品牌

# %%
#可以先创建dict，然后在转成dataframe，这样可以避免行号不一致限制
result = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in data_d.items()]))

# %%
result
# Out:
#              不限         专用车品牌          卡车品牌  封闭货车品牌         工程车品牌   微型车品牌  \
# 0            奔驰     安徽大田(秋浦牌)            奔驰     比亚迪     安徽星马(星马牌)     北京牌
# 1          北奔重卡            奔驰          北奔重卡    北汽威旺          北奔重卡    北汽威旺
# 2          北汽黑豹          北奔重卡          北汽黑豹    长安跨越          北方重工    北汽幻速
# 3           比亚迪          北汽黑豹           比亚迪   长安轻型车           别拉斯    长安跨越
# 4           北京牌           比亚迪           北京牌    东风股份          北方交通   长安轻型车
# 5         北汽新能源           冰凌方           BMC   东风商用车            贝尔    昌河汽车
# 6           BMC     北京北铃(北铃牌)          北汽威旺    东风华神     长春双龙(龙帝牌)    成功汽车
# 7          北汽威旺     北京天路(天路牌)          长安跨越    东风小康         东风商用车    东风股份
# 8          宝骐汽车     北京科力（科力牌）         长安轻型车    东风超龙          东风柳汽    东风小康
# 9           博雷顿          长安跨越          昌河汽车    东风客车          东风华神    东南汽车
# 10         北斗航天         长安轻型车          川交汽车    东南汽车          大运重卡   福田商务车
# 11         北汽幻速          昌河汽车          长征汽车   福田商务车  东风新疆(原专底/创普)    福田伽途
# 12         长安跨越     常州中汽(常奇牌)          长安重汽    福田伽途        达夫/DAF    福汽启腾
# 13        长安轻型车     长沙中联(中联牌)          东风股份    福田祥菱            斗山    广汽吉奥
# 14         长城汽车     滁州永强(永强牌)         东风凯普特    福特汽车          福田欧曼  华晨鑫源金杯
# 15         昌河汽车     长春双龙(龙帝牌)         东风多利卡    福建奔驰          福田瑞沃      哈飞
# 16         川交汽车          驰田汽车     东风福瑞卡(全新)  华晨鑫源金杯          飞碟奥驰    海马汽车
# 17         长征汽车   滁州长久(恒信致远牌)          东风力拓    黄海汽车          抚挖重工    开瑞汽车
# 18         长丰集团         东风商用车        东风电动轻卡    华晨雷诺          广汽日野      力帆
# 19         长安重汽          东风柳汽          东风途逸    海格汽车          湖北大运    上汽五菱
# 20         长江汽车         东风多利卡        东风天然气车    沈阳金杯            华菱    时空电动
# 3         锣响挂车       北汽威旺   长丰汽车       安途生
# 4        烈牛半挂车       宝骐汽车   成功汽车       埃贝赫
# 5         梁山长虹        博雷顿   东风股份      安徽巨一
# 6         梁山盛源       北斗航天     东风        安中
# 7         梁山中泽       长安跨越     大众       埃尔曼
# 8         梁山新宇      长安轻型车     道奇        奔驰
# 9         欧阳聚德       昌河汽车   福田皮卡      北奔重卡
# 10   深圳中集(深扬帆)       长江汽车   福特汽车      博格思众
# 11        山东骏通       成都雅骏   丰田汽车  BPW(梅州)桥
# 12        中集华骏       东风股份   福迪汽车       倍耐力
# 13        中集瑞江  东风福瑞卡(全新)   广汽吉奥      北汽福田
# 14     中集(中集牌)     东风电动轻卡   黄海汽车     北内柴油机
# 15        郓城华威       东风柳汽   海格汽车        暴享
# 16         NaN       大运轻卡   恒天汽车        宝石
# 17         NaN       东风华神   绵阳金杯       波波娃
# 18         NaN       大运重卡   江铃汽车        朝柴
# 19         NaN         大众  江西五十铃       采埃孚
# 20         NaN     达夫/DAF   江淮皮卡        常柴
# 21         NaN      东风瑞泰特   江淮安驰        成山
# 22         NaN       东风捍蓝     凯马      长城动力
# 23         NaN       德力汽车   开瑞汽车      长城机油
# 24         NaN       福田时代     卡威      朝阳浪马
# 25         NaN      福田欧马可   绵阳金杯      昌河铃木
# 26         NaN       福田奥铃   美国通用      成发汽发
# 27         NaN      福田商务车   明君汽车        苍泰
# 28         NaN       福田伽途   南骏汽车      成功淮海
# 29         NaN       福田祥菱     庆铃      绰丰柳机
# ..         ...        ...    ...       ...
# 176        NaN        NaN    NaN      新光华晨
# 177        NaN        NaN    NaN      西安双特
# 178        NaN        NaN    NaN      新光华翔
# 179        NaN        NaN    NaN       鑫聚力
# 180        NaN        NaN    NaN        兴龙
# 181        NaN        NaN    NaN      一汽解放
# 182        NaN        NaN    NaN        玉柴
# 183        NaN        NaN    NaN      云内动力
# 184        NaN        NaN    NaN        扬柴
# 185        NaN        NaN    NaN      樱花轮胎
# 186        NaN        NaN    NaN        伊顿
# 187        NaN        NaN    NaN        亿利
# 188        NaN        NaN    NaN      溢通环保
# 189        NaN        NaN    NaN        扬动
# 190        NaN        NaN    NaN      一汽四环
# 191        NaN        NaN    NaN        一汽
# 192        NaN        NaN    NaN        雅士
# 193        NaN        NaN    NaN    渝安淮海动力
# 194        NaN        NaN    NaN       义和桥
# 195        NaN        NaN    NaN       英得尔
# 196        NaN        NaN    NaN       优迪狮
# 197        NaN        NaN    NaN        雅固
# 198        NaN        NaN    NaN      中国重汽
# 199        NaN        NaN    NaN        正新
# 200        NaN        NaN    NaN        綦齿
# 201        NaN        NaN    NaN      重庆长安
# 202        NaN        NaN    NaN      浙江万丰
# 203        NaN        NaN    NaN     重庆康明斯
# 204        NaN        NaN    NaN      正兴车轮
# 205        NaN        NaN    NaN       中联桥
#
# [206 rows x 10 columns]

# %%
result.to_csv("truck_home.csv",encoding="utf_8_sig",index=True)
