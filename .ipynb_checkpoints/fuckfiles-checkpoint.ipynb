# %%
import os
dirpaths=[]
fileph=[]
filenms=[]
def copyingremoveInitPath(allthings):
    for file in allthings:
        print("目前的路径：",os.getcwd())
        juduipath=os.getcwd()
        newpath=os.path.join(juduipath,file)+"/"
        if os.path.isdir(newpath):
            print("这是个文件夹:",newpath)
            os.chdir(file)
            
            print("目前的路径1：",os.getcwd())
            fanhui=aquireDetails(os.getcwd())
            copyingremoveInitPath(fanhui)
        else:
            filename = os.path.splitext(file)[0];  
            filetype = os.path.splitext(file)[1]; 
            filePath=path+filename+filetype
            newname=path+filename
            print("开始复制:","copy"+" "+filename+filetype+" "+filename+".html")
            

def aquireDetails(path):
    allthings=os.listdir(path)
    return allthings

def copyFiles(allthings):
    #print("current folder:",os.getcwd())
    for file in allthings:
        Olddir = os.path.join(path, file)+"/"
        abspath=os.path.join(os.getcwd(),Olddir)
        print("current abspath:",abspath)
        if os.path.isdir(abspath):     #这个必须是绝对路径才能使用，晕！
            print("this is a folder,now,display it:",file)
            os.chdir(path+"/"+file)
           
            print("current folder,should be entired,otherwise,the operation isn't correct!",os.getcwd())
            details=aquireDetails(os.getcwd())
            #copyFiles(details)
            copyingremoveInitPath(details)
        else:
            filename = os.path.splitext(file)[0];  
            filetype = os.path.splitext(file)[1]; 
            filePath=path+filename+filetype
            newname=path+filename
            print("copying operation now")
            #os.system("copy"+" "+filename+filetype+" "+filename+".html")
            #print ("current operation folder and processing details::",os.getcwd(),"copy"+" "+filename+filetype+" "+filename+".html")


    
        
if __name__ =="__main__":
    """
    #print "plz ensure the input folder only containing single layer folder,no folder inside anymore"
    print "<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>"
    print "<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>"
    print "<<<<<<<<<<    Rule One: plz ensure the input folder only containing>>>>>>>>>>>>>" 
    print "<<<<<<<<<<    single layer folder,no folder inside anymore        >>>>>>>>>>>>>>"
    print "<<<<<<<<<<    Rule Two: eg.input test11// or test11//dw_base      >>>>>>>>>>>>>>"
    print "<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>"
    print "<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>"
    """
    path=input("input the path of folders::")
    
    k=aquireDetails(path)
    copyFiles(k)
    print("files in above folders copied done!!!!!!!",fileph)
# Out:
# input the path of folders::shiyan
# current abspath: /home/wx/Downloads/pythoncode/shiyan/canif_cbk.h/
# copying operation now
# current abspath: /home/wx/Downloads/pythoncode/shiyan/canif_priv.h/
# copying operation now
# current abspath: /home/wx/Downloads/pythoncode/shiyan/can.h/
# copying operation now
# current abspath: /home/wx/Downloads/pythoncode/shiyan/canif.h/
# copying operation now
# current abspath: /home/wx/Downloads/pythoncode/shiyan/arc_api/
# this is a folder,now,display it: arc_api
# current folder,should be entired,otherwise,the operation isn't correct! /home/wx/Downloads/pythoncode/shiyan/arc_api
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api
# 开始复制: copy canif_cbk.h canif_cbk.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api
# 开始复制: copy BitArray_Common.h BitArray_Common.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api
# 开始复制: copy AgeingMeter_Config_Common.h AgeingMeter_Config_Common.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api
# 开始复制: copy canif_types.h canif_types.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api
# 开始复制: copy Adc_Prv_Zynq_Types.h Adc_Prv_Zynq_Types.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api
# 开始复制: copy AsrtStat.h AsrtStat.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api
# 开始复制: copy cansm.h cansm.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api
# 开始复制: copy AgeingMeter_Common.h AgeingMeter_Common.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api
# 开始复制: copy AgeingMeter_Customer.h AgeingMeter_Customer.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api
# 开始复制: copy canif_priv.h canif_priv.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api
# 这是个文件夹: /home/wx/Downloads/pythoncode/shiyan/arc_api/fixed/
# 目前的路径1： /home/wx/Downloads/pythoncode/shiyan/arc_api/fixed
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api/fixed
# 开始复制: copy can.h can.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api/fixed
# 开始复制: copy canif.h canif.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api/fixed
# 开始复制: copy AgeingMeterEeprom_Common.h AgeingMeterEeprom_Common.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api/fixed
# 开始复制: copy ha ha.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api/fixed
# 开始复制: copy Adc_Prv_Zynq.h Adc_Prv_Zynq.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api/fixed
# 开始复制: copy can_cfg.h can_cfg.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api/fixed
# 开始复制: copy canif_cfg.h canif_cfg.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api/fixed
# 开始复制: copy can_types.h can_types.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api/fixed
# 开始复制: copy Can_Prv.h Can_Prv.html
# 目前的路径： /home/wx/Downloads/pythoncode/shiyan/arc_api/fixed
# 开始复制: copy Can_Cfg_Time.h Can_Cfg_Time.html
# current abspath: /home/wx/Downloads/pythoncode/shiyan/arc_api/fixed/shiyan/can_cfg.h/
# copying operation now
# current abspath: /home/wx/Downloads/pythoncode/shiyan/arc_api/fixed/shiyan/canif_cfg.h/
# copying operation now
# current abspath: /home/wx/Downloads/pythoncode/shiyan/arc_api/fixed/shiyan/Can_Cfg_Time.h/
# copying operation now
# files in above folders copied done!!!!!!! []

# %%
k
